# %%
VERSION = '22_v2_01'
FOLD_PATH = '../../00_EDA/00_v2_07/result/' #'../../00_EDA/00_v1_01/result/'
MODEL = 'microsoft/deberta-xlarge'
#'microsoft/deberta-large'
#'microsoft/deberta-base'
#'microsoft/deberta-v3-base'
#'funnel-transformer/xlarge'
#'ahotrod/electra_large_discriminator_squad2_512'
#'funnel-transformer/xlarge'
#'microsoft/deberta-v3-large'
#'microsoft/deberta-large'
#'anferico/bert-for-patents'
#'microsoft/deberta-v3-base'
#'microsoft/cocolm-large'
LR = 6e-6 #8e-6 #2e-5
HEAD_LR = 6e-6 #8e-6 #2e-5
SEED = 100
TRN_BS = 1
VAL_BS = 1
ACCUM_STEP = 1
EPOCHS = 5 #2
STOP_EPOCH = EPOCHS #5 #2
RESTART = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
LOSS = 'xentropy'
HEAD = 'simple'
AUG = 'false' #'mixup'
MIXUP_ALPHA = 1.0
P_AUG = 0
AUG_STOP_EPOCH = 2
MSD = 'true'
MULTI_LAYERS = 1
EVAL_STEP = -1 #100
NUM_LABELS = 3
NUM_LABELS_2 = 7
ADV_SIFT = 'false'
FP16 = 'true' #'false'
WD = 0.01
FREEZE = 'true'
#MAX_LENGTH = 1024
MULTI_TASK = 'false' #'true'
W_MT = 1.0 #0.5
#PREPROCESSED_DATA_PATH = '../../00_EDA/00_v2_01/result/train.csv'
#'../../00_EDA/00_v1_09/result/train.csv'
AWP = 'true'
AWP_LR = 1e-4 #5e-4 #1e-2 #1.0
AWP_EPS = 1e-3 #0.01
AWP_START_EPOCH = 1

#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_xlarge_fold0.pth'
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_large_fold0.pth'
#PRETRAINED_DETECTOR_PATH = f'../../05_Detection/exp/result/05_v1_04/model_seed100_fold0_swa.pth'
PRETRAINED_DETECTOR_PATH = 'none'

PRETRAINED_MLM_PATH = f'../../21_MLM2/exp/result/21_v2_14/model_gen_seed2022_fold0_swa.pth'

MASK_PROB = 0.8
MASK_RATIO = 0.3

SCHEDULER = 'cosine_hard'
NUM_CYCLES = EPOCHS

CP = 'true'

WINDOW_SIZE = 1024 #768 #512
INNER_LEN = 768 #512 #384
EDGE_LEN = 128 #64

BNB = 32

# %%
FOLD = 0

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB \
--pretrained_mlm_path $PRETRAINED_MLM_PATH
# Out:
# torch 1.10.2
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29462, 6)
# val_df.shape =  (7303, 6)
# 2022-07-31 08:06:29.892435: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-07-31 08:06:29.892455: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  16760
# num_warmup_steps =  1676
# lr :  [0.0, 0.0, 0.0]
# 100%|████████████████████████████| 3352/3352 [45:18<00:00,  1.23it/s, loss=1.52]
# 100%|█████████████████████████████████████████| 839/839 [01:59<00:00,  7.00it/s]
# epoch 1: trn_loss = 1.5233, val_loss = 0.6292, trn_score = -0.7579, val_score = -0.6292
# model (best loss) saved
# model (best score) saved
# lr :  [2.4790554669992093e-06, 2.4790554669992093e-06, 2.4790554669992093e-06]
# 100%|████████████████████████████| 3352/3352 [45:12<00:00,  1.24it/s, loss=1.27]
# 100%|█████████████████████████████████████████| 839/839 [02:00<00:00,  6.99it/s]
# epoch 2: trn_loss = 1.2676, val_loss = 0.6086, trn_score = -0.6306, val_score = -0.6086
# model (best loss) saved
# model (best score) saved
# lr :  [1.500000000000002e-06, 1.500000000000002e-06, 1.500000000000002e-06]
# 100%|████████████████████████████| 3352/3352 [45:18<00:00,  1.23it/s, loss=1.19]
# 100%|█████████████████████████████████████████| 839/839 [02:00<00:00,  6.99it/s]
# epoch 3: trn_loss = 1.1878, val_loss = 0.6048, trn_score = -0.5897, val_score = -0.6048
# model (best loss) saved
# model (best score) saved
# lr :  [7.018666706430663e-07, 7.018666706430663e-07, 7.018666706430663e-07]
# 100%|████████████████████████████| 3352/3352 [45:07<00:00,  1.24it/s, loss=1.14]
# 100%|█████████████████████████████████████████| 839/839 [02:00<00:00,  6.99it/s]
# epoch 4: trn_loss = 1.1384, val_loss = 0.6024, trn_score = -0.5645, val_score = -0.6024
# model (best loss) saved
# model (best score) saved
# lr :  [1.8092213764227505e-07, 1.8092213764227505e-07, 1.8092213764227505e-07]
# 100%|████████████████████████████| 3352/3352 [43:42<00:00,  1.28it/s, loss=1.55]
# 100%|█████████████████████████████████████████| 839/839 [02:00<00:00,  6.99it/s]
# epoch 5: trn_loss = 1.5536, val_loss = 0.9878, trn_score = -0.7750, val_score = -0.9878
# epoch_best 4, val_loss_best 0.60243, val_score_best -0.60243

# %%
FOLD = 1

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB \
--pretrained_mlm_path $PRETRAINED_MLM_PATH
# Out:
# torch 1.10.2
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29383, 6)
# val_df.shape =  (7382, 6)
# 2022-07-31 12:02:19.964817: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-07-31 12:02:19.964838: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  16765
# num_warmup_steps =  1676
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 3353/3353 [44:13<00:00,  1.26it/s, loss=1.9]
# 100%|█████████████████████████████████████████| 838/838 [01:59<00:00,  7.01it/s]
# epoch 1: trn_loss = 1.8956, val_loss = 0.9819, trn_score = -0.9466, val_score = -0.9819
# model (best loss) saved
# model (best score) saved
# lr :  [2.4776885822975693e-06, 2.4776885822975693e-06, 2.4776885822975693e-06]
#   5%|█▍                           | 171/3353 [02:09<40:41,  1.30it/s, loss=1.94]^C
#   5%|█▍                           | 171/3353 [02:09<40:09,  1.32it/s, loss=1.94]
# Traceback (most recent call last):
#   File "../22_v2_01/train.py", line 149, in <module>
#     run(args, trn_df, val_df, pseudo_df=None)
#   File "/home/takesako2/programming/kaggle/54_Feedback2/22_BaselineMLM/22_v2_01/run.py", line 195, in run
#     scaler.scale(loss).backward()
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/_tensor.py", line 307, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/autograd/__init__.py", line 156, in backward
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/takesako2/anaconda3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
# Traceback (most recent call last):
#   File "/home/takesako2/anaconda3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/home/takesako2/anaconda3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/takesako2/anaconda3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/home/takesako2/anaconda3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/takesako2/anaconda3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/takesako2/anaconda3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/takesako2/anaconda3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/takesako2/anaconda3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/home/takesako2/anaconda3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/takesako2/anaconda3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
#   File "/home/takesako2/anaconda3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
#     allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#   File "/home/takesako2/anaconda3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
# KeyboardInterrupt
#   File "/home/takesako2/anaconda3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
# BrokenPipeError: [Errno 32] Broken pipe
#   File "/home/takesako2/anaconda3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/takesako2/anaconda3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe

# %%
AWP_LR = 5e-5 #1e-4 #5e-4 #1e-2 #1.0
AWP_EPS = 1e-3 #0.01

FOLD = 1

RESTART = 1
PRETRAIN_PATH = 'none' #f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{RESTART-1}.pth'


# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB \
--pretrained_mlm_path $PRETRAINED_MLM_PATH --pretrain_path $PRETRAIN_PATH
# Out:
# torch 1.10.2
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29383, 6)
# val_df.shape =  (7382, 6)
# 2022-08-01 00:47:34.691816: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-08-01 00:47:34.691838: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  16765
# num_warmup_steps =  1676
# lr :  [0.0, 0.0, 0.0]
# 100%|████████████████████████████| 3353/3353 [45:34<00:00,  1.23it/s, loss=1.51]
# 100%|█████████████████████████████████████████| 838/838 [01:59<00:00,  7.02it/s]
# epoch 1: trn_loss = 1.5074, val_loss = 0.7248, trn_score = -0.7517, val_score = -0.7248
# model (best loss) saved
# model (best score) saved
# lr :  [2.4776885822975693e-06, 2.4776885822975693e-06, 2.4776885822975693e-06]
# 100%|████████████████████████████| 3353/3353 [45:32<00:00,  1.23it/s, loss=1.27]
# 100%|█████████████████████████████████████████| 838/838 [01:58<00:00,  7.08it/s]
# epoch 2: trn_loss = 1.2652, val_loss = 0.6294, trn_score = -0.6309, val_score = -0.6294
# model (best loss) saved
# model (best score) saved
# lr :  [1.4990985398458688e-06, 1.4990985398458688e-06, 1.4990985398458688e-06]
# 100%|████████████████████████████| 3353/3353 [44:19<00:00,  1.26it/s, loss=1.63]
# 100%|█████████████████████████████████████████| 838/838 [02:00<00:00,  6.95it/s]
# epoch 3: trn_loss = 1.6278, val_loss = 0.9844, trn_score = -0.8131, val_score = -0.9844
# lr :  [7.014206286156537e-07, 7.014206286156537e-07, 7.014206286156537e-07]
# 100%|████████████████████████████| 3353/3353 [43:22<00:00,  1.29it/s, loss=1.98]
# 100%|█████████████████████████████████████████| 838/838 [01:58<00:00,  7.07it/s]
# epoch 4: trn_loss = 1.9839, val_loss = 0.9845, trn_score = -0.9919, val_score = -0.9845
# lr :  [1.8080347313698008e-07, 1.8080347313698008e-07, 1.8080347313698008e-07]
# 100%|████████████████████████████| 3353/3353 [43:31<00:00,  1.28it/s, loss=1.98]
# 100%|█████████████████████████████████████████| 838/838 [01:59<00:00,  6.99it/s]
# epoch 5: trn_loss = 1.9832, val_loss = 0.9840, trn_score = -0.9915, val_score = -0.9840
# epoch_best 2, val_loss_best 0.62942, val_score_best -0.62942

# %%
AWP_LR = 1e-4 #5e-4 #1e-2 #1.0
AWP_EPS = 1e-3 #0.01

FOLD = 1

RESTART = 3
PRETRAIN_PATH = f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{RESTART-1}.pth'

GRAD_CLIP = 1000

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB \
--pretrained_mlm_path $PRETRAINED_MLM_PATH --pretrain_path $PRETRAIN_PATH \
--gradient_clip_val $GRAD_CLIP
# Out:
# torch 1.10.2
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29383, 6)
# val_df.shape =  (7382, 6)
# 2022-08-01 05:09:52.518455: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-08-01 05:09:52.518477: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  16765
# num_warmup_steps =  1676
# epoch =  1
# 100%|██████████████████████████████████████| 3353/3353 [00:11<00:00, 297.49it/s]
# epoch =  2
# 100%|██████████████████████████████████████| 3353/3353 [00:11<00:00, 296.58it/s]
# lr :  [1.4990985398458688e-06, 1.4990985398458688e-06, 1.4990985398458688e-06]
# 100%|████████████████████████████| 3353/3353 [45:10<00:00,  1.24it/s, loss=1.18]
# 100%|█████████████████████████████████████████| 838/838 [01:56<00:00,  7.21it/s]
# epoch 3: trn_loss = 1.1815, val_loss = 0.6244, trn_score = -0.5868, val_score = -0.6244
# model (best loss) saved
# model (best score) saved
# lr :  [7.014206286156537e-07, 7.014206286156537e-07, 7.014206286156537e-07]
# 100%|█████████████████████████████| 3353/3353 [44:46<00:00,  1.25it/s, loss=1.1]
# 100%|█████████████████████████████████████████| 838/838 [01:57<00:00,  7.11it/s]
# epoch 4: trn_loss = 1.1033, val_loss = 0.6176, trn_score = -0.5480, val_score = -0.6176
# model (best loss) saved
# model (best score) saved
# lr :  [1.8080347313698008e-07, 1.8080347313698008e-07, 1.8080347313698008e-07]
# 100%|████████████████████████████| 3353/3353 [45:17<00:00,  1.23it/s, loss=1.03]
# 100%|█████████████████████████████████████████| 838/838 [01:59<00:00,  7.02it/s]
# epoch 5: trn_loss = 1.0319, val_loss = 0.6273, trn_score = -0.5110, val_score = -0.6273
# epoch_best 4, val_loss_best 0.61755, val_score_best -0.61755

# %%
FOLD = 2

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB \
--pretrained_mlm_path $PRETRAINED_MLM_PATH
# Out:
# torch 1.10.2
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29461, 6)
# val_df.shape =  (7304, 6)
# 2022-07-31 12:51:12.453761: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-07-31 12:51:12.453784: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  16765
# num_warmup_steps =  1676
# lr :  [0.0, 0.0, 0.0]
# 100%|████████████████████████████| 3353/3353 [45:07<00:00,  1.24it/s, loss=1.55]
# 100%|█████████████████████████████████████████| 838/838 [02:02<00:00,  6.85it/s]
# epoch 1: trn_loss = 1.5469, val_loss = 0.6474, trn_score = -0.7694, val_score = -0.6474
# model (best loss) saved
# model (best score) saved
# lr :  [2.4776885822975693e-06, 2.4776885822975693e-06, 2.4776885822975693e-06]
# 100%|█████████████████████████████| 3353/3353 [45:13<00:00,  1.24it/s, loss=1.3]
# 100%|█████████████████████████████████████████| 838/838 [02:03<00:00,  6.80it/s]
# epoch 2: trn_loss = 1.3044, val_loss = 0.6256, trn_score = -0.6488, val_score = -0.6256
# model (best loss) saved
# model (best score) saved
# lr :  [1.4990985398458688e-06, 1.4990985398458688e-06, 1.4990985398458688e-06]
# 100%|████████████████████████████| 3353/3353 [45:05<00:00,  1.24it/s, loss=1.22]
# 100%|█████████████████████████████████████████| 838/838 [02:03<00:00,  6.79it/s]
# epoch 3: trn_loss = 1.2194, val_loss = 0.6062, trn_score = -0.6064, val_score = -0.6062
# model (best loss) saved
# model (best score) saved
# lr :  [7.014206286156537e-07, 7.014206286156537e-07, 7.014206286156537e-07]
# 100%|████████████████████████████| 3353/3353 [45:06<00:00,  1.24it/s, loss=1.17]
# 100%|█████████████████████████████████████████| 838/838 [02:02<00:00,  6.83it/s]
# epoch 4: trn_loss = 1.1676, val_loss = 0.6139, trn_score = -0.5800, val_score = -0.6139
# lr :  [1.8080347313698008e-07, 1.8080347313698008e-07, 1.8080347313698008e-07]
# 100%|████████████████████████████| 3353/3353 [44:54<00:00,  1.24it/s, loss=1.08]
# 100%|█████████████████████████████████████████| 838/838 [02:02<00:00,  6.87it/s]
# epoch 5: trn_loss = 1.0839, val_loss = 0.6129, trn_score = -0.5375, val_score = -0.6129
# epoch_best 3, val_loss_best 0.60624, val_score_best -0.60624

# %%
FOLD = 3

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB \
--pretrained_mlm_path $PRETRAINED_MLM_PATH
# Out:
# torch 1.10.2
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29348, 6)
# val_df.shape =  (7417, 6)
# 2022-07-31 16:47:55.373084: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-07-31 16:47:55.373104: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  16765
# num_warmup_steps =  1676
# lr :  [0.0, 0.0, 0.0]
# 100%|████████████████████████████| 3353/3353 [46:56<00:00,  1.19it/s, loss=1.54]
# 100%|█████████████████████████████████████████| 838/838 [01:59<00:00,  7.04it/s]
# epoch 1: trn_loss = 1.5401, val_loss = 0.6665, trn_score = -0.7666, val_score = -0.6665
# model (best loss) saved
# model (best score) saved
# lr :  [2.4776885822975693e-06, 2.4776885822975693e-06, 2.4776885822975693e-06]
# 100%|████████████████████████████| 3353/3353 [45:46<00:00,  1.22it/s, loss=1.28]
# 100%|█████████████████████████████████████████| 838/838 [01:59<00:00,  7.04it/s]
# epoch 2: trn_loss = 1.2766, val_loss = 0.6293, trn_score = -0.6345, val_score = -0.6293
# model (best loss) saved
# model (best score) saved
# lr :  [1.4990985398458688e-06, 1.4990985398458688e-06, 1.4990985398458688e-06]
# 100%|█████████████████████████████| 3353/3353 [45:37<00:00,  1.22it/s, loss=1.2]
# 100%|█████████████████████████████████████████| 838/838 [02:00<00:00,  6.98it/s]
# epoch 3: trn_loss = 1.1973, val_loss = 0.6416, trn_score = -0.5948, val_score = -0.6416
# lr :  [7.014206286156537e-07, 7.014206286156537e-07, 7.014206286156537e-07]
#  60%|█████████████████▎           | 2003/3353 [26:49<15:10,  1.48it/s, loss=1.3]^C
#  60%|█████████████████▎           | 2004/3353 [26:50<18:04,  1.24it/s, loss=1.3]
# Traceback (most recent call last):
#   File "../22_v2_01/train.py", line 149, in <module>
#     run(args, trn_df, val_df, pseudo_df=None)
#   File "/home/takesako2/programming/kaggle/54_Feedback2/22_BaselineMLM/22_v2_01/run.py", line 192, in run
#     pred, label, loss = model.training_step(data)
#   File "/home/takesako2/programming/kaggle/54_Feedback2/22_BaselineMLM/22_v2_01/models.py", line 407, in training_step
#     logits = self.forward_logits(**input_data)
#   File "/home/takesako2/programming/kaggle/54_Feedback2/22_BaselineMLM/22_v2_01/models.py", line 295, in forward_logits
#     attention_mask=attention_mask).last_hidden_state
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/transformers/models/deberta/modeling_deberta.py", line 959, in forward
#     return_dict=return_dict,
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/transformers/models/deberta/modeling_deberta.py", line 444, in forward
#     rel_embeddings,
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/utils/checkpoint.py", line 211, in checkpoint
#     return CheckpointFunction.apply(function, preserve, *args)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/utils/checkpoint.py", line 90, in forward
#     outputs = run_function(*args)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/transformers/models/deberta/modeling_deberta.py", line 434, in custom_forward
#     return module(*inputs, output_attentions)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/transformers/models/deberta/modeling_deberta.py", line 358, in forward
#     rel_embeddings=rel_embeddings,
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/transformers/models/deberta/modeling_deberta.py", line 291, in forward
#     rel_embeddings=rel_embeddings,
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/transformers/models/deberta/modeling_deberta.py", line 634, in forward
#     query_layer = query_layer / scale
# KeyboardInterrupt

# %%
AWP_LR = 5e-5 #1e-4 #5e-4 #1e-2 #1.0
AWP_EPS = 1e-3 #0.01

FOLD = 3

RESTART = 4
PRETRAIN_PATH = f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{RESTART-1}.pth'


# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB \
--pretrained_mlm_path $PRETRAINED_MLM_PATH --pretrain_path $PRETRAIN_PATH
# Out:
# torch 1.10.2
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29348, 6)
# val_df.shape =  (7417, 6)
# 2022-07-31 23:12:12.205616: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-07-31 23:12:12.205639: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  16765
# num_warmup_steps =  1676
# epoch =  1
# 100%|██████████████████████████████████████| 3353/3353 [00:11<00:00, 292.21it/s]
# epoch =  2
# 100%|██████████████████████████████████████| 3353/3353 [00:11<00:00, 287.91it/s]
# epoch =  3
# 100%|██████████████████████████████████████| 3353/3353 [00:11<00:00, 283.13it/s]
# lr :  [7.014206286156537e-07, 7.014206286156537e-07, 7.014206286156537e-07]
# 100%|████████████████████████████| 3353/3353 [45:07<00:00,  1.24it/s, loss=1.02]
# 100%|█████████████████████████████████████████| 838/838 [01:58<00:00,  7.07it/s]
# epoch 4: trn_loss = 1.0249, val_loss = 0.6440, trn_score = -0.5096, val_score = -0.6440
# model (best loss) saved
# model (best score) saved
# lr :  [1.8080347313698008e-07, 1.8080347313698008e-07, 1.8080347313698008e-07]
# 100%|████████████████████████████| 3353/3353 [45:05<00:00,  1.24it/s, loss=1.01]
# 100%|█████████████████████████████████████████| 838/838 [01:57<00:00,  7.12it/s]
# epoch 5: trn_loss = 1.0112, val_loss = 0.6473, trn_score = -0.5029, val_score = -0.6473
# epoch_best 4, val_loss_best 0.64397, val_score_best -0.64397

# %%
AWP_LR = 1e-4 #5e-4 #1e-2 #1.0
AWP_EPS = 1e-3 #0.01

FOLD = 3

RESTART = 3
PRETRAIN_PATH = f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{RESTART-1}.pth'
GRAD_CLIP = 1000


# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB \
--pretrained_mlm_path $PRETRAINED_MLM_PATH --pretrain_path $PRETRAIN_PATH \
--gradient_clip_val $GRAD_CLIP
# Out:
# torch 1.10.2
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29348, 6)
# val_df.shape =  (7417, 6)
# 2022-08-01 07:32:19.566194: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-08-01 07:32:19.566216: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  16765
# num_warmup_steps =  1676
# epoch =  1
# 100%|██████████████████████████████████████| 3353/3353 [00:11<00:00, 297.77it/s]
# epoch =  2
# 100%|██████████████████████████████████████| 3353/3353 [00:11<00:00, 296.01it/s]
# lr :  [1.4990985398458688e-06, 1.4990985398458688e-06, 1.4990985398458688e-06]
# 100%|████████████████████████████| 3353/3353 [45:28<00:00,  1.23it/s, loss=1.18]
# 100%|█████████████████████████████████████████| 838/838 [02:00<00:00,  6.93it/s]
# epoch 3: trn_loss = 1.1815, val_loss = 0.6186, trn_score = -0.5867, val_score = -0.6186
# model (best loss) saved
# model (best score) saved
# lr :  [7.014206286156537e-07, 7.014206286156537e-07, 7.014206286156537e-07]
# 100%|████████████████████████████| 3353/3353 [45:26<00:00,  1.23it/s, loss=1.12]
# 100%|█████████████████████████████████████████| 838/838 [02:00<00:00,  6.93it/s]
# epoch 4: trn_loss = 1.1167, val_loss = 0.6176, trn_score = -0.5539, val_score = -0.6176
# model (best loss) saved
# model (best score) saved
# lr :  [1.8080347313698008e-07, 1.8080347313698008e-07, 1.8080347313698008e-07]
# 100%|████████████████████████████| 3353/3353 [45:31<00:00,  1.23it/s, loss=1.03]
# 100%|█████████████████████████████████████████| 838/838 [01:59<00:00,  7.00it/s]
# epoch 5: trn_loss = 1.0279, val_loss = 0.6405, trn_score = -0.5093, val_score = -0.6405
# epoch_best 4, val_loss_best 0.61756, val_score_best -0.61756

# %%
FOLD = 4

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB \
--pretrained_mlm_path $PRETRAINED_MLM_PATH
# Out:
# torch 1.10.2
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29406, 6)
# val_df.shape =  (7359, 6)
# 2022-07-31 19:39:50.677508: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-07-31 19:39:50.677530: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  16765
# num_warmup_steps =  1676
# lr :  [0.0, 0.0, 0.0]
# 100%|████████████████████████████| 3353/3353 [45:32<00:00,  1.23it/s, loss=1.54]
# 100%|█████████████████████████████████████████| 838/838 [01:59<00:00,  6.99it/s]
# epoch 1: trn_loss = 1.5426, val_loss = 0.7063, trn_score = -0.7672, val_score = -0.7063
# model (best loss) saved
# model (best score) saved
# lr :  [2.4776885822975693e-06, 2.4776885822975693e-06, 2.4776885822975693e-06]
# 100%|████████████████████████████| 3353/3353 [45:34<00:00,  1.23it/s, loss=1.29]
# 100%|█████████████████████████████████████████| 838/838 [02:01<00:00,  6.91it/s]
# epoch 2: trn_loss = 1.2869, val_loss = 0.6289, trn_score = -0.6399, val_score = -0.6289
# model (best loss) saved
# model (best score) saved
# lr :  [1.4990985398458688e-06, 1.4990985398458688e-06, 1.4990985398458688e-06]
# 100%|█████████████████████████████| 3353/3353 [45:31<00:00,  1.23it/s, loss=1.2]
# 100%|█████████████████████████████████████████| 838/838 [02:00<00:00,  6.97it/s]
# epoch 3: trn_loss = 1.2049, val_loss = 0.6182, trn_score = -0.5981, val_score = -0.6182
# model (best loss) saved
# model (best score) saved
# lr :  [7.014206286156537e-07, 7.014206286156537e-07, 7.014206286156537e-07]
# 100%|████████████████████████████| 3353/3353 [45:34<00:00,  1.23it/s, loss=1.14]
# 100%|█████████████████████████████████████████| 838/838 [02:01<00:00,  6.89it/s]
# epoch 4: trn_loss = 1.1370, val_loss = 0.6075, trn_score = -0.5645, val_score = -0.6075
# model (best loss) saved
# model (best score) saved
# lr :  [1.8080347313698008e-07, 1.8080347313698008e-07, 1.8080347313698008e-07]
#  45%|████████████▍               | 1496/3353 [20:56<20:07,  1.54it/s, loss=1.44]^C
#  45%|████████████▍               | 1496/3353 [20:56<25:59,  1.19it/s, loss=1.44]
# Traceback (most recent call last):
#   File "../22_v2_01/train.py", line 149, in <module>
#     run(args, trn_df, val_df, pseudo_df=None)
#   File "/home/takesako2/programming/kaggle/54_Feedback2/22_BaselineMLM/22_v2_01/run.py", line 195, in run
#     scaler.scale(loss).backward()
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/_tensor.py", line 307, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/autograd/__init__.py", line 156, in backward
#     allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
# KeyboardInterrupt

# %% [markdown]
# # SWA

# %%
# !python ../$VERSION/swa.py --work_dir ./result/$VERSION/ --fold 0 --seed $SEED --epochs '2 3 4'
# !python ../$VERSION/swa.py --work_dir ./result/$VERSION/ --fold 1 --seed $SEED --epochs '3 4 5'
# !python ../$VERSION/swa.py --work_dir ./result/$VERSION/ --fold 2 --seed $SEED --epochs '3 4 5'
# !python ../$VERSION/swa.py --work_dir ./result/$VERSION/ --fold 3 --seed $SEED --epochs '3 4'
# !python ../$VERSION/swa.py --work_dir ./result/$VERSION/ --fold 4 --seed $SEED --epochs '4'

# %%
FOLD = 0
WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}_swa.pth'

# !python ../$VERSION/validation.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
--rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN
# Out:
# torch 1.10.2
# 2022-08-01 10:00:25.097817: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-08-01 10:00:25.097840: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29462, 6)
# val_df.shape =  (7303, 6)
# 100%|█████████████████████████████████████████| 839/839 [01:13<00:00, 11.49it/s]
# val_loss=0.5964, val_score=-0.5964
# preds.shape =  (7303, 3)
# labels.shape =  (7303,)
# losses.shape =  (7303,)
# discourse_ids.shape =  (7303,)

# %%
FOLD = 1
WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}_swa.pth'

# !python ../$VERSION/validation.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
--rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN
# Out:
# torch 1.10.2
# 2022-08-01 10:02:00.099538: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-08-01 10:02:00.099560: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29383, 6)
# val_df.shape =  (7382, 6)
# 100%|█████████████████████████████████████████| 838/838 [01:13<00:00, 11.37it/s]
# val_loss=0.6146, val_score=-0.6146
# preds.shape =  (7382, 3)
# labels.shape =  (7382,)
# losses.shape =  (7382,)
# discourse_ids.shape =  (7382,)

# %%
FOLD = 2
WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}_swa.pth'

# !python ../$VERSION/validation.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
--rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN
# Out:
# torch 1.10.2
# 2022-08-01 10:03:35.606278: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-08-01 10:03:35.606301: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29461, 6)
# val_df.shape =  (7304, 6)
# 100%|█████████████████████████████████████████| 838/838 [01:17<00:00, 10.87it/s]
# val_loss=0.6021, val_score=-0.6021
# preds.shape =  (7304, 3)
# labels.shape =  (7304,)
# losses.shape =  (7304,)
# discourse_ids.shape =  (7304,)

# %%
FOLD = 3
WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}_swa.pth'

# !python ../$VERSION/validation.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
--rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN
# Out:
# torch 1.10.2
# 2022-08-01 10:05:14.699171: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-08-01 10:05:14.699194: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29348, 6)
# val_df.shape =  (7417, 6)
# 100%|█████████████████████████████████████████| 838/838 [01:14<00:00, 11.31it/s]
# val_loss=0.6132, val_score=-0.6132
# preds.shape =  (7417, 3)
# labels.shape =  (7417,)
# losses.shape =  (7417,)
# discourse_ids.shape =  (7417,)

# %%
FOLD = 4
WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}_swa.pth'

# !python ../$VERSION/validation.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
--rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN
# Out:
# torch 1.10.2
# 2022-08-01 10:06:50.717076: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-08-01 10:06:50.717099: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29406, 6)
# val_df.shape =  (7359, 6)
# 100%|█████████████████████████████████████████| 838/838 [01:15<00:00, 11.04it/s]
# val_loss=0.6075, val_score=-0.6075
# preds.shape =  (7359, 3)
# labels.shape =  (7359,)
# losses.shape =  (7359,)
# discourse_ids.shape =  (7359,)

# %%
import pandas as pd

preds = []
for fold in range(5):
    tmp_df = pd.read_csv(f'./result/{VERSION}/pred_fold{fold}.csv')
    preds.append(tmp_df)
    
pred_df = pd.concat(preds, axis=0).reset_index(drop=True)
train_df = pd.read_csv('../../input/feedback-prize-effectiveness/train.csv')

oof_df = train_df.merge(pred_df, on='discourse_id', how='left')
oof_df.to_csv(f'./result/{VERSION}/oof_df.csv', index=False)

# %%
oof_df.shape, oof_df.isnull().sum()
# Out:
# ((36765, 10),
#  discourse_id               0
#  essay_id                   0
#  discourse_text             0
#  discourse_type             0
#  discourse_effectiveness    0
#  pred_ineffective           0
#  pred_adequate              0
#  pred_effective             0
#  label                      0
#  loss                       0
#  dtype: int64)
