# %%
VERSION = '18_v2_22'
FOLD_PATH = '../../00_EDA/00_v2_07/result/' #'../../00_EDA/00_v1_01/result/'
MODEL = 'microsoft/deberta-v2-xlarge'
#'microsoft/deberta-xlarge'
#'microsoft/deberta-large'
#'microsoft/deberta-base'
#'microsoft/deberta-v3-base'
#'funnel-transformer/xlarge'
#'ahotrod/electra_large_discriminator_squad2_512'
#'funnel-transformer/xlarge'
#'microsoft/deberta-v3-large'
#'microsoft/deberta-large'
#'anferico/bert-for-patents'
#'microsoft/deberta-v3-base'
#'microsoft/cocolm-large'
LR = 6e-6 #8e-6 #2e-5
HEAD_LR = 6e-6 #8e-6 #2e-5
SEED = 100
TRN_BS = 1
VAL_BS = 1
ACCUM_STEP = 1
EPOCHS = 6 #5 #2
STOP_EPOCH = 6 #5 #2
RESTART = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
LOSS = 'xentropy'
HEAD = 'simple'
AUG = 'false' #'mixup'
MIXUP_ALPHA = 1.0
P_AUG = 0
AUG_STOP_EPOCH = 2
MSD = 'true'
MULTI_LAYERS = 1
EVAL_STEP = -1 #100
NUM_LABELS = 3
NUM_LABELS_2 = 7
ADV_SIFT = 'false'
FP16 = 'true' #'false'
WD = 0.01
FREEZE = 'true'
#MAX_LENGTH = 1024
MULTI_TASK = 'false' #'true'
W_MT = 1.0 #0.5
#PREPROCESSED_DATA_PATH = '../../00_EDA/00_v2_01/result/train.csv'
#'../../00_EDA/00_v1_09/result/train.csv'
AWP = 'true'
AWP_LR = 1e-4 #1e-2 #1.0
AWP_EPS = 1e-3 #0.01
AWP_START_EPOCH = 1

#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_xlarge_fold0.pth'
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_large_fold0.pth'
#PRETRAINED_DETECTOR_PATH = f'../../05_Detection/exp/result/05_v1_04/model_seed100_fold0_swa.pth'
PRETRAINED_DETECTOR_PATH = f'../../05_Detection/exp/result/05_v2_11/model_seed100_fold0_swa.pth'

MASK_PROB = 0.5 #0.8
MASK_RATIO = 0.22 #0.3

SCHEDULER = 'cosine_hard'
NUM_CYCLES = EPOCHS

CP = 'true'

WINDOW_SIZE = 1024 #768 #512
INNER_LEN = 768 #512 #384
EDGE_LEN = 128 #64

BNB = 32

# %%
FOLD = 0

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB
# Out:
# torch 1.10.2
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29462, 6)
# val_df.shape =  (7303, 6)
# 2022-07-26 12:48:14.269888: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-07-26 12:48:14.269909: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  20112
# num_warmup_steps =  2011
# lr :  [0.0, 0.0, 0.0]
# 100%|████████████████████████████| 3352/3352 [31:02<00:00,  1.80it/s, loss=1.51]
# 100%|█████████████████████████████████████████| 839/839 [02:00<00:00,  6.98it/s]
# epoch 1: trn_loss = 1.5083, val_loss = 0.6366, trn_score = -0.7514, val_score = -0.6366
# model (best loss) saved
# model (best score) saved
# lr :  [3.520374782271735e-06, 3.520374782271735e-06, 3.520374782271735e-06]
# 100%|████████████████████████████| 3352/3352 [30:33<00:00,  1.83it/s, loss=1.25]
# 100%|█████████████████████████████████████████| 839/839 [01:55<00:00,  7.29it/s]
# epoch 2: trn_loss = 1.2471, val_loss = 0.6232, trn_score = -0.6204, val_score = -0.6232
# model (best loss) saved
# model (best score) saved
# lr :  [2.4785996803636427e-06, 2.4785996803636427e-06, 2.4785996803636427e-06]
# 100%|████████████████████████████| 3352/3352 [30:04<00:00,  1.86it/s, loss=1.16]
# 100%|█████████████████████████████████████████| 839/839 [01:54<00:00,  7.35it/s]
# epoch 3: trn_loss = 1.1592, val_loss = 0.6107, trn_score = -0.5775, val_score = -0.6107
# model (best loss) saved
# model (best score) saved
# lr :  [1.4996993969211692e-06, 1.4996993969211692e-06, 1.4996993969211692e-06]
# 100%|█████████████████████████████| 3352/3352 [30:23<00:00,  1.84it/s, loss=1.1]
# 100%|█████████████████████████████████████████| 839/839 [01:55<00:00,  7.29it/s]
# epoch 4: trn_loss = 1.0954, val_loss = 0.5865, trn_score = -0.5446, val_score = -0.5865
# model (best loss) saved
# model (best score) saved
# lr :  [7.017179286574643e-07, 7.017179286574643e-07, 7.017179286574643e-07]
# 100%|████████████████████████████| 3352/3352 [30:44<00:00,  1.82it/s, loss=1.01]
# 100%|█████████████████████████████████████████| 839/839 [01:55<00:00,  7.29it/s]
# epoch 5: trn_loss = 1.0140, val_loss = 0.6062, trn_score = -0.5043, val_score = -0.6062
# lr :  [1.808825659412834e-07, 1.808825659412834e-07, 1.808825659412834e-07]
# 100%|███████████████████████████| 3352/3352 [30:31<00:00,  1.83it/s, loss=0.931]
# 100%|█████████████████████████████████████████| 839/839 [01:54<00:00,  7.32it/s]
# epoch 6: trn_loss = 0.9310, val_loss = 0.6126, trn_score = -0.4614, val_score = -0.6126
# epoch_best 4, val_loss_best 0.58650, val_score_best -0.58650

# %%
FOLD = 1

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB
# Out:
# torch 1.10.2
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29383, 6)
# val_df.shape =  (7382, 6)
# 2022-07-26 16:04:29.850137: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-07-26 16:04:29.850159: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  20118
# num_warmup_steps =  2011
# lr :  [0.0, 0.0, 0.0]
# 100%|████████████████████████████| 3353/3353 [31:13<00:00,  1.79it/s, loss=1.52]
# 100%|█████████████████████████████████████████| 838/838 [01:58<00:00,  7.07it/s]
# epoch 1: trn_loss = 1.5183, val_loss = 0.6528, trn_score = -0.7567, val_score = -0.6528
# model (best loss) saved
# model (best score) saved
# lr :  [3.5186661693254884e-06, 3.5186661693254884e-06, 3.5186661693254884e-06]
# 100%|████████████████████████████| 3353/3353 [29:54<00:00,  1.87it/s, loss=1.25]
# 100%|█████████████████████████████████████████| 838/838 [01:55<00:00,  7.24it/s]
# epoch 2: trn_loss = 1.2514, val_loss = 0.6246, trn_score = -0.6220, val_score = -0.6246
# model (best loss) saved
# model (best score) saved
# lr :  [2.4772329990251676e-06, 2.4772329990251676e-06, 2.4772329990251676e-06]
# 100%|████████████████████████████| 3353/3353 [29:59<00:00,  1.86it/s, loss=1.19]
# 100%|█████████████████████████████████████████| 838/838 [01:54<00:00,  7.34it/s]
# epoch 3: trn_loss = 1.1873, val_loss = 0.6282, trn_score = -0.5914, val_score = -0.6282
# lr :  [1.498798106558355e-06, 1.498798106558355e-06, 1.498798106558355e-06]
# 100%|█████████████████████████████| 3353/3353 [30:12<00:00,  1.85it/s, loss=1.1]
# 100%|█████████████████████████████████████████| 838/838 [01:54<00:00,  7.31it/s]
# epoch 4: trn_loss = 1.1008, val_loss = 0.6216, trn_score = -0.5479, val_score = -0.6216
# model (best loss) saved
# model (best score) saved
# lr :  [7.012719818425146e-07, 7.012719818425146e-07, 7.012719818425146e-07]
# 100%|████████████████████████████| 3353/3353 [30:24<00:00,  1.84it/s, loss=1.02]
# 100%|█████████████████████████████████████████| 838/838 [01:53<00:00,  7.38it/s]
# epoch 5: trn_loss = 1.0172, val_loss = 0.6212, trn_score = -0.5057, val_score = -0.6212
# model (best loss) saved
# model (best score) saved
# lr :  [1.8076392843092538e-07, 1.8076392843092538e-07, 1.8076392843092538e-07]
# 100%|███████████████████████████| 3353/3353 [29:54<00:00,  1.87it/s, loss=0.921]
# 100%|█████████████████████████████████████████| 838/838 [01:55<00:00,  7.29it/s]
# epoch 6: trn_loss = 0.9212, val_loss = 0.6518, trn_score = -0.4579, val_score = -0.6518
# epoch_best 5, val_loss_best 0.62122, val_score_best -0.62122

# %%
FOLD = 2

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB
# Out:
# torch 1.10.2
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29461, 6)
# val_df.shape =  (7304, 6)
# 2022-07-26 19:19:02.721513: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-07-26 19:19:02.721532: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  20118
# num_warmup_steps =  2011
# lr :  [0.0, 0.0, 0.0]
# 100%|████████████████████████████| 3353/3353 [30:34<00:00,  1.83it/s, loss=1.53]
# 100%|█████████████████████████████████████████| 838/838 [02:03<00:00,  6.80it/s]
# epoch 1: trn_loss = 1.5308, val_loss = 0.6454, trn_score = -0.7625, val_score = -0.6454
# model (best loss) saved
# model (best score) saved
# lr :  [3.5186661693254884e-06, 3.5186661693254884e-06, 3.5186661693254884e-06]
# 100%|████████████████████████████| 3353/3353 [29:53<00:00,  1.87it/s, loss=1.26]
# 100%|█████████████████████████████████████████| 838/838 [01:58<00:00,  7.06it/s]
# epoch 2: trn_loss = 1.2646, val_loss = 0.6230, trn_score = -0.6295, val_score = -0.6230
# model (best loss) saved
# model (best score) saved
# lr :  [2.4772329990251676e-06, 2.4772329990251676e-06, 2.4772329990251676e-06]
# 100%|████████████████████████████| 3353/3353 [29:32<00:00,  1.89it/s, loss=1.54]
# 100%|█████████████████████████████████████████| 838/838 [01:57<00:00,  7.11it/s]
# epoch 3: trn_loss = 1.5431, val_loss = 0.9238, trn_score = -0.7710, val_score = -0.9238
# lr :  [1.498798106558355e-06, 1.498798106558355e-06, 1.498798106558355e-06]
#   1%|▏                             | 25/3353 [00:12<20:06,  2.76it/s, loss=1.85]^C
#   1%|▏                             | 25/3353 [00:13<28:56,  1.92it/s, loss=1.85]
# Traceback (most recent call last):
#   File "../18_v2_22/train.py", line 148, in <module>
#     run(args, trn_df, val_df, pseudo_df=None)
#   File "/home/takesako2/programming/kaggle/54_Feedback2/18_BaselineSW/18_v2_22/run.py", line 194, in run
#     scaler.scale(loss).backward()
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/_tensor.py", line 307, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/autograd/__init__.py", line 156, in backward
#     allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
# KeyboardInterrupt

# %%
RESTART = 3
MASK_PROB = 0.5 #0.8
MASK_RATIO = 0.15 #0.22 #0.3

FOLD = 2

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB

RESTART = 1
MASK_PROB = 0.5 #0.8
MASK_RATIO = 0.22 #0.3
# Out:
# torch 1.10.2
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29461, 6)
# val_df.shape =  (7304, 6)
# 2022-07-27 03:23:46.696428: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-07-27 03:23:46.696449: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  20118
# num_warmup_steps =  2011
# epoch =  1
# 100%|██████████████████████████████████████| 3353/3353 [00:10<00:00, 319.74it/s]
# epoch =  2
# 100%|██████████████████████████████████████| 3353/3353 [00:10<00:00, 322.11it/s]
# lr :  [2.4772329990251676e-06, 2.4772329990251676e-06, 2.4772329990251676e-06]
# 100%|████████████████████████████| 3353/3353 [29:46<00:00,  1.88it/s, loss=1.48]
# 100%|█████████████████████████████████████████| 838/838 [01:59<00:00,  6.99it/s]
# epoch 3: trn_loss = 1.4759, val_loss = 0.6465, trn_score = -0.7359, val_score = -0.6465
# model (best loss) saved
# model (best score) saved
# lr :  [1.498798106558355e-06, 1.498798106558355e-06, 1.498798106558355e-06]
# 100%|████████████████████████████| 3353/3353 [29:20<00:00,  1.90it/s, loss=1.28]
# 100%|█████████████████████████████████████████| 838/838 [01:53<00:00,  7.40it/s]
# epoch 4: trn_loss = 1.2827, val_loss = 0.6078, trn_score = -0.6394, val_score = -0.6078
# model (best loss) saved
# model (best score) saved
# lr :  [7.012719818425146e-07, 7.012719818425146e-07, 7.012719818425146e-07]
# 100%|█████████████████████████████| 3353/3353 [29:13<00:00,  1.91it/s, loss=1.2]
# 100%|█████████████████████████████████████████| 838/838 [01:53<00:00,  7.37it/s]
# epoch 5: trn_loss = 1.2013, val_loss = 0.6070, trn_score = -0.5970, val_score = -0.6070
# model (best loss) saved
# model (best score) saved
# lr :  [1.8076392843092538e-07, 1.8076392843092538e-07, 1.8076392843092538e-07]
# 100%|████████████████████████████| 3353/3353 [28:59<00:00,  1.93it/s, loss=1.12]
# 100%|█████████████████████████████████████████| 838/838 [01:52<00:00,  7.42it/s]
# epoch 6: trn_loss = 1.1161, val_loss = 0.5945, trn_score = -0.5552, val_score = -0.5945
# model (best loss) saved
# model (best score) saved
# epoch_best 6, val_loss_best 0.59452, val_score_best -0.59452

# %%
FOLD = 3

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB
# Out:
# torch 1.10.2
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29348, 6)
# val_df.shape =  (7417, 6)
# 2022-07-26 20:56:05.039016: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-07-26 20:56:05.039039: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  20118
# num_warmup_steps =  2011
# lr :  [0.0, 0.0, 0.0]
# 100%|████████████████████████████| 3353/3353 [30:36<00:00,  1.83it/s, loss=1.51]
# 100%|█████████████████████████████████████████| 838/838 [01:59<00:00,  7.03it/s]
# epoch 1: trn_loss = 1.5087, val_loss = 0.6796, trn_score = -0.7505, val_score = -0.6796
# model (best loss) saved
# model (best score) saved
# lr :  [3.5186661693254884e-06, 3.5186661693254884e-06, 3.5186661693254884e-06]
# 100%|████████████████████████████| 3353/3353 [29:57<00:00,  1.87it/s, loss=1.24]
# 100%|█████████████████████████████████████████| 838/838 [01:55<00:00,  7.27it/s]
# epoch 2: trn_loss = 1.2429, val_loss = 0.6388, trn_score = -0.6187, val_score = -0.6388
# model (best loss) saved
# model (best score) saved
# lr :  [2.4772329990251676e-06, 2.4772329990251676e-06, 2.4772329990251676e-06]
# 100%|████████████████████████████| 3353/3353 [30:08<00:00,  1.85it/s, loss=1.19]
# 100%|█████████████████████████████████████████| 838/838 [01:55<00:00,  7.28it/s]
# epoch 3: trn_loss = 1.1856, val_loss = 0.6347, trn_score = -0.5896, val_score = -0.6347
# model (best loss) saved
# model (best score) saved
# lr :  [1.498798106558355e-06, 1.498798106558355e-06, 1.498798106558355e-06]
# 100%|████████████████████████████| 3353/3353 [30:07<00:00,  1.85it/s, loss=1.11]
# 100%|█████████████████████████████████████████| 838/838 [01:56<00:00,  7.22it/s]
# epoch 4: trn_loss = 1.1132, val_loss = 0.6185, trn_score = -0.5531, val_score = -0.6185
# model (best loss) saved
# model (best score) saved
# lr :  [7.012719818425146e-07, 7.012719818425146e-07, 7.012719818425146e-07]
# 100%|████████████████████████████| 3353/3353 [29:57<00:00,  1.87it/s, loss=1.04]
# 100%|█████████████████████████████████████████| 838/838 [01:54<00:00,  7.35it/s]
# epoch 5: trn_loss = 1.0413, val_loss = 0.6302, trn_score = -0.5167, val_score = -0.6302
# lr :  [1.8076392843092538e-07, 1.8076392843092538e-07, 1.8076392843092538e-07]
# 100%|███████████████████████████| 3353/3353 [29:57<00:00,  1.87it/s, loss=0.953]
# 100%|█████████████████████████████████████████| 838/838 [01:53<00:00,  7.37it/s]
# epoch 6: trn_loss = 0.9531, val_loss = 0.6477, trn_score = -0.4739, val_score = -0.6477
# epoch_best 4, val_loss_best 0.61849, val_score_best -0.61849

# %%
FOLD = 4

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB
# Out:
# torch 1.10.2
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29406, 6)
# val_df.shape =  (7359, 6)
# 2022-07-27 00:09:46.402251: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-07-27 00:09:46.402279: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  20118
# num_warmup_steps =  2011
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 3353/3353 [31:29<00:00,  1.77it/s, loss=1.5]
# 100%|█████████████████████████████████████████| 838/838 [02:01<00:00,  6.90it/s]
# epoch 1: trn_loss = 1.5003, val_loss = 0.6581, trn_score = -0.7467, val_score = -0.6581
# model (best loss) saved
# model (best score) saved
# lr :  [3.5186661693254884e-06, 3.5186661693254884e-06, 3.5186661693254884e-06]
# 100%|████████████████████████████| 3353/3353 [30:23<00:00,  1.84it/s, loss=1.23]
# 100%|█████████████████████████████████████████| 838/838 [01:50<00:00,  7.57it/s]
# epoch 2: trn_loss = 1.2345, val_loss = 0.6216, trn_score = -0.6136, val_score = -0.6216
# model (best loss) saved
# model (best score) saved
# lr :  [2.4772329990251676e-06, 2.4772329990251676e-06, 2.4772329990251676e-06]
# 100%|████████████████████████████| 3353/3353 [30:02<00:00,  1.86it/s, loss=1.17]
# 100%|█████████████████████████████████████████| 838/838 [01:51<00:00,  7.51it/s]
# epoch 3: trn_loss = 1.1691, val_loss = 0.6199, trn_score = -0.5819, val_score = -0.6199
# model (best loss) saved
# model (best score) saved
# lr :  [1.498798106558355e-06, 1.498798106558355e-06, 1.498798106558355e-06]
# 100%|████████████████████████████| 3353/3353 [30:01<00:00,  1.86it/s, loss=1.09]
# 100%|█████████████████████████████████████████| 838/838 [01:51<00:00,  7.52it/s]
# epoch 4: trn_loss = 1.0864, val_loss = 0.6129, trn_score = -0.5413, val_score = -0.6129
# model (best loss) saved
# model (best score) saved
# lr :  [7.012719818425146e-07, 7.012719818425146e-07, 7.012719818425146e-07]
# 100%|███████████████████████████| 3353/3353 [30:02<00:00,  1.86it/s, loss=0.989]
# 100%|█████████████████████████████████████████| 838/838 [01:50<00:00,  7.56it/s]
# epoch 5: trn_loss = 0.9895, val_loss = 0.6212, trn_score = -0.4918, val_score = -0.6212
# lr :  [1.8076392843092538e-07, 1.8076392843092538e-07, 1.8076392843092538e-07]
# 100%|████████████████████████████| 3353/3353 [29:24<00:00,  1.90it/s, loss=0.89]
# 100%|█████████████████████████████████████████| 838/838 [01:50<00:00,  7.59it/s]
# epoch 6: trn_loss = 0.8896, val_loss = 0.6468, trn_score = -0.4411, val_score = -0.6468
# epoch_best 4, val_loss_best 0.61292, val_score_best -0.61292

# %% [markdown]
# # SWA

# %%
# !python ../$VERSION/swa.py --work_dir ./result/$VERSION/ --fold 0 --seed $SEED --epochs '4'
# !python ../$VERSION/swa.py --work_dir ./result/$VERSION/ --fold 1 --seed $SEED --epochs '4 5'
# !python ../$VERSION/swa.py --work_dir ./result/$VERSION/ --fold 2 --seed $SEED --epochs '4 5 6'
# !python ../$VERSION/swa.py --work_dir ./result/$VERSION/ --fold 3 --seed $SEED --epochs '4'
# !python ../$VERSION/swa.py --work_dir ./result/$VERSION/ --fold 4 --seed $SEED --epochs '2 3 4 5'

# %%
FOLD = 0
WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}_swa.pth'

# !python ../$VERSION/validation.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
--rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN
# Out:
# torch 1.10.2
# 2022-07-27 06:20:40.723909: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-07-27 06:20:40.723932: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29462, 6)
# val_df.shape =  (7303, 6)
# 100%|█████████████████████████████████████████| 839/839 [01:13<00:00, 11.41it/s]
# val_loss=0.5865, val_score=-0.5865
# preds.shape =  (7303, 3)
# labels.shape =  (7303,)
# losses.shape =  (7303,)
# discourse_ids.shape =  (7303,)

# %%
FOLD = 1
WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}_swa.pth'

# !python ../$VERSION/validation.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
--rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN
# Out:
# torch 1.10.2
# 2022-07-27 06:11:29.716077: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-07-27 06:11:29.716100: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29383, 6)
# val_df.shape =  (7382, 6)
# 100%|█████████████████████████████████████████| 838/838 [01:13<00:00, 11.42it/s]
# val_loss=0.6155, val_score=-0.6155
# preds.shape =  (7382, 3)
# labels.shape =  (7382,)
# losses.shape =  (7382,)
# discourse_ids.shape =  (7382,)

# %%
FOLD = 2
WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}_swa.pth'

# !python ../$VERSION/validation.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
--rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN
# Out:
# torch 1.10.2
# 2022-07-27 06:13:03.640495: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-07-27 06:13:03.640519: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29461, 6)
# val_df.shape =  (7304, 6)
# 100%|█████████████████████████████████████████| 838/838 [01:18<00:00, 10.74it/s]
# val_loss=0.5937, val_score=-0.5937
# preds.shape =  (7304, 3)
# labels.shape =  (7304,)
# losses.shape =  (7304,)
# discourse_ids.shape =  (7304,)

# %%
FOLD = 3
WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}_swa.pth'

# !python ../$VERSION/validation.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
--rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN
# Out:
# torch 1.10.2
# 2022-07-27 06:22:14.879177: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-07-27 06:22:14.879200: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29348, 6)
# val_df.shape =  (7417, 6)
# 100%|█████████████████████████████████████████| 838/838 [01:13<00:00, 11.38it/s]
# val_loss=0.6185, val_score=-0.6185
# preds.shape =  (7417, 3)
# labels.shape =  (7417,)
# losses.shape =  (7417,)
# discourse_ids.shape =  (7417,)

# %%
FOLD = 4
WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}_swa.pth'

# !python ../$VERSION/validation.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
--rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN
# Out:
# torch 1.10.2
# 2022-07-27 06:14:42.234232: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-07-27 06:14:42.234255: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29406, 6)
# val_df.shape =  (7359, 6)
# 100%|█████████████████████████████████████████| 838/838 [01:14<00:00, 11.25it/s]
# val_loss=0.6058, val_score=-0.6058
# preds.shape =  (7359, 3)
# labels.shape =  (7359,)
# losses.shape =  (7359,)
# discourse_ids.shape =  (7359,)

# %%
import pandas as pd

preds = []
for fold in range(5):
    tmp_df = pd.read_csv(f'./result/{VERSION}/pred_fold{fold}.csv')
    preds.append(tmp_df)
    
pred_df = pd.concat(preds, axis=0).reset_index(drop=True)
train_df = pd.read_csv('../../input/feedback-prize-effectiveness/train.csv')

oof_df = train_df.merge(pred_df, on='discourse_id', how='left')
oof_df.to_csv(f'./result/{VERSION}/oof_df.csv', index=False)

# %%
oof_df.shape, oof_df.isnull().sum()
# Out:
# ((36765, 10),
#  discourse_id               0
#  essay_id                   0
#  discourse_text             0
#  discourse_type             0
#  discourse_effectiveness    0
#  pred_ineffective           0
#  pred_adequate              0
#  pred_effective             0
#  label                      0
#  loss                       0
#  dtype: int64)
