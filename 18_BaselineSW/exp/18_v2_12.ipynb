# %%
VERSION = '18_v2_12'
FOLD_PATH = '../../00_EDA/00_v2_07/result/' #'../../00_EDA/00_v1_01/result/'
MODEL = 'microsoft/deberta-xlarge'
#'microsoft/deberta-large'
#'microsoft/deberta-base'
#'microsoft/deberta-v3-base'
#'funnel-transformer/xlarge'
#'ahotrod/electra_large_discriminator_squad2_512'
#'funnel-transformer/xlarge'
#'microsoft/deberta-v3-large'
#'microsoft/deberta-large'
#'anferico/bert-for-patents'
#'microsoft/deberta-v3-base'
#'microsoft/cocolm-large'
LR = 6e-6 #8e-6 #2e-5
HEAD_LR = 6e-6 #8e-6 #2e-5
SEED = 100
TRN_BS = 1
VAL_BS = 1
ACCUM_STEP = 1
EPOCHS = 5 #2
STOP_EPOCH = 5 #2
RESTART = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
LOSS = 'xentropy'
HEAD = 'simple'
AUG = 'false' #'mixup'
MIXUP_ALPHA = 1.0
P_AUG = 0
AUG_STOP_EPOCH = 2
MSD = 'true'
MULTI_LAYERS = 1
EVAL_STEP = -1 #100
NUM_LABELS = 3
NUM_LABELS_2 = 7
ADV_SIFT = 'false'
FP16 = 'true' #'false'
WD = 0.01
FREEZE = 'true'
#MAX_LENGTH = 1024
MULTI_TASK = 'false' #'true'
W_MT = 1.0 #0.5
#PREPROCESSED_DATA_PATH = '../../00_EDA/00_v2_01/result/train.csv'
#'../../00_EDA/00_v1_09/result/train.csv'
AWP = 'true'
AWP_LR = 5e-4 #1e-2 #1.0
AWP_EPS = 1e-3 #0.01
AWP_START_EPOCH = 1

PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_xlarge_fold0.pth'
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_large_fold0.pth'
#PRETRAINED_DETECTOR_PATH = f'../../05_Detection/exp/result/05_v1_04/model_seed100_fold0_swa.pth'

MASK_PROB = 0.8
MASK_RATIO = 0.3

SCHEDULER = 'cosine_hard'
NUM_CYCLES = EPOCHS

CP = 'true'

WINDOW_SIZE = 512
INNER_LEN = 384
EDGE_LEN = 64

BNB = 32

# %%
FOLD = 0

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB
# Out:
# torch 1.10.2
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29462, 6)
# val_df.shape =  (7303, 6)
# 2022-07-23 05:46:31.202849: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-07-23 05:46:31.202872: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  16760
# num_warmup_steps =  1676
# lr :  [0.0, 0.0, 0.0]
# 100%|████████████████████████████| 3352/3352 [48:36<00:00,  1.15it/s, loss=1.62]
# 100%|█████████████████████████████████████████| 839/839 [01:59<00:00,  7.04it/s]
# epoch 1: trn_loss = 1.6172, val_loss = 0.6597, trn_score = -0.7960, val_score = -0.6597
# model (best loss) saved
# model (best score) saved
# lr :  [2.4790554669992093e-06, 2.4790554669992093e-06, 2.4790554669992093e-06]
# 100%|████████████████████████████| 3352/3352 [48:52<00:00,  1.14it/s, loss=1.36]
# 100%|█████████████████████████████████████████| 839/839 [01:59<00:00,  7.03it/s]
# epoch 2: trn_loss = 1.3556, val_loss = 0.6761, trn_score = -0.6668, val_score = -0.6761
# lr :  [1.500000000000002e-06, 1.500000000000002e-06, 1.500000000000002e-06]
# 100%|████████████████████████████| 3352/3352 [48:46<00:00,  1.15it/s, loss=1.75]
# 100%|█████████████████████████████████████████| 839/839 [02:00<00:00,  6.94it/s]
# epoch 3: trn_loss = 1.7510, val_loss = 0.9923, trn_score = -0.8724, val_score = -0.9923
# lr :  [7.018666706430663e-07, 7.018666706430663e-07, 7.018666706430663e-07]
#   0%|                               | 4/3352 [00:03<50:44,  1.10it/s, loss=1.78]^C
#   0%|                               | 4/3352 [00:04<58:20,  1.05s/it, loss=1.78]
# Traceback (most recent call last):
#   File "../18_v2_12/train.py", line 148, in <module>
#     run(args, trn_df, val_df, pseudo_df=None)
#   File "/home/takesako2/programming/kaggle/54_Feedback2/18_BaselineSW/18_v2_12/run.py", line 190, in run
#     loss = awp.attack_backward(data)
#   File "/home/takesako2/programming/kaggle/54_Feedback2/18_BaselineSW/18_v2_12/awp.py", line 35, in attack_backward
#     _, _, adv_loss = self.model.training_step(inputs)
#   File "/home/takesako2/programming/kaggle/54_Feedback2/18_BaselineSW/18_v2_12/models.py", line 407, in training_step
#     logits = self.forward_logits(**input_data)
#   File "/home/takesako2/programming/kaggle/54_Feedback2/18_BaselineSW/18_v2_12/models.py", line 303, in forward_logits
#     attention_mask=attention_mask[:,:self.window_size]).last_hidden_state
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/transformers/models/deberta/modeling_deberta.py", line 959, in forward
#     return_dict=return_dict,
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/transformers/models/deberta/modeling_deberta.py", line 444, in forward
#     rel_embeddings,
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/utils/checkpoint.py", line 211, in checkpoint
#     return CheckpointFunction.apply(function, preserve, *args)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/utils/checkpoint.py", line 90, in forward
#     outputs = run_function(*args)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/transformers/models/deberta/modeling_deberta.py", line 434, in custom_forward
#     return module(*inputs, output_attentions)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/transformers/models/deberta/modeling_deberta.py", line 358, in forward
#     rel_embeddings=rel_embeddings,
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/transformers/models/deberta/modeling_deberta.py", line 291, in forward
#     rel_embeddings=rel_embeddings,
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/transformers/models/deberta/modeling_deberta.py", line 638, in forward
#     rel_att = self.disentangled_att_bias(query_layer, key_layer, relative_pos, rel_embeddings, scale_factor)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/transformers/models/deberta/modeling_deberta.py", line 685, in disentangled_att_bias
#     c2p_att = torch.matmul(query_layer, pos_key_layer.transpose(-1, -2))
# KeyboardInterrupt

# %%
FOLD = 1

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB

# %%
FOLD = 2

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB

# %%
FOLD = 3

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB

# %%
FOLD = 4

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB
