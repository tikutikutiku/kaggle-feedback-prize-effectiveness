# %%
VERSION = '18_v2_19'
FOLD_PATH = '../../00_EDA/00_v2_07/result/' #'../../00_EDA/00_v1_01/result/'
MODEL = 'microsoft/deberta-large'
#'microsoft/deberta-xlarge'
#'microsoft/deberta-base'
#'microsoft/deberta-v3-base'
#'funnel-transformer/xlarge'
#'ahotrod/electra_large_discriminator_squad2_512'
#'funnel-transformer/xlarge'
#'microsoft/deberta-v3-large'
#'microsoft/deberta-large'
#'anferico/bert-for-patents'
#'microsoft/deberta-v3-base'
#'microsoft/cocolm-large'
LR = 8e-6 #2e-5
HEAD_LR = 8e-6 #2e-5
SEED = 100
TRN_BS = 1
VAL_BS = 1
ACCUM_STEP = 1
EPOCHS = 6 #5 #2
STOP_EPOCH = 6 #5 #2
RESTART = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
LOSS = 'xentropy'
HEAD = 'simple'
AUG = 'false' #'mixup'
MIXUP_ALPHA = 1.0
P_AUG = 0
AUG_STOP_EPOCH = 2
MSD = 'true'
MULTI_LAYERS = 1
EVAL_STEP = -1 #100
NUM_LABELS = 3
NUM_LABELS_2 = 7
ADV_SIFT = 'false'
FP16 = 'true' #'false'
WD = 0.01
FREEZE = 'false'
#MAX_LENGTH = 1024
MULTI_TASK = 'false' #'true'
W_MT = 1.0 #0.5
#PREPROCESSED_DATA_PATH = '../../00_EDA/00_v2_01/result/train.csv'
#'../../00_EDA/00_v1_09/result/train.csv'
AWP = 'true'
AWP_LR = 1e-2 #1.0
AWP_EPS = 1e-3 #0.01
AWP_START_EPOCH = 1

#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_xlarge_fold0.pth'
PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_large_fold0.pth'
#PRETRAINED_DETECTOR_PATH = f'../../05_Detection/exp/result/05_v1_04/model_seed100_fold0_swa.pth'

MASK_PROB = 0.8
MASK_RATIO = 0.3

SCHEDULER = 'cosine_hard'
NUM_CYCLES = EPOCHS

CP = 'false'

WINDOW_SIZE = 768 #512
INNER_LEN = 512 #384
EDGE_LEN = 128 #64

BNB = 32

# %%
FOLD = 0

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB
# Out:
# torch 1.10.2
# train_df.shape =  (36765, 5)
# test_df.shape =  (10, 4)
# sub_df.shape =  (10, 4)
# load folds...
# trn_df.shape =  (29462, 6)
# val_df.shape =  (7303, 6)
# 2022-07-23 23:38:01.974446: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-07-23 23:38:01.974468: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  20112
# num_warmup_steps =  2011
# lr :  [0.0, 0.0, 0.0]
# 100%|████████████████████████████| 3352/3352 [21:22<00:00,  2.61it/s, loss=1.54]
# 100%|█████████████████████████████████████████| 839/839 [01:24<00:00,  9.92it/s]
# epoch 1: trn_loss = 1.5420, val_loss = 0.6487, trn_score = -0.7512, val_score = -0.6487
# model (best loss) saved
# model (best score) saved
# lr :  [4.69383304302898e-06, 4.69383304302898e-06, 4.69383304302898e-06]
# 100%|████████████████████████████| 3352/3352 [21:31<00:00,  2.59it/s, loss=1.27]
# 100%|█████████████████████████████████████████| 839/839 [01:25<00:00,  9.79it/s]
# epoch 2: trn_loss = 1.2671, val_loss = 0.6444, trn_score = -0.6181, val_score = -0.6444
# model (best loss) saved
# model (best score) saved
# lr :  [3.30479957381819e-06, 3.30479957381819e-06, 3.30479957381819e-06]
# 100%|████████████████████████████| 3352/3352 [21:59<00:00,  2.54it/s, loss=1.18]
# 100%|█████████████████████████████████████████| 839/839 [01:25<00:00,  9.83it/s]
# epoch 3: trn_loss = 1.1761, val_loss = 0.6072, trn_score = -0.5718, val_score = -0.6072
# model (best loss) saved
# model (best score) saved
# lr :  [1.999599195894892e-06, 1.999599195894892e-06, 1.999599195894892e-06]
# 100%|████████████████████████████| 3352/3352 [22:10<00:00,  2.52it/s, loss=1.08]
# 100%|█████████████████████████████████████████| 839/839 [01:26<00:00,  9.73it/s]
# epoch 4: trn_loss = 1.0834, val_loss = 0.6023, trn_score = -0.5246, val_score = -0.6023
# model (best loss) saved
# model (best score) saved
# lr :  [9.35623904876619e-07, 9.35623904876619e-07, 9.35623904876619e-07]
# 100%|████████████████████████████| 3352/3352 [22:10<00:00,  2.52it/s, loss=1.01]
# 100%|█████████████████████████████████████████| 839/839 [01:25<00:00,  9.84it/s]
# epoch 5: trn_loss = 1.0057, val_loss = 0.5992, trn_score = -0.4851, val_score = -0.5992
# model (best loss) saved
# model (best score) saved
# lr :  [2.4117675458837786e-07, 2.4117675458837786e-07, 2.4117675458837786e-07]
# 100%|███████████████████████████| 3352/3352 [22:11<00:00,  2.52it/s, loss=0.942]
# 100%|█████████████████████████████████████████| 839/839 [01:26<00:00,  9.74it/s]
# epoch 6: trn_loss = 0.9417, val_loss = 0.6270, trn_score = -0.4510, val_score = -0.6270
# epoch_best 5, val_loss_best 0.59916, val_score_best -0.59916

# %%
FOLD = 1

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB

# %%
FOLD = 2

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB

# %%
FOLD = 3

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB

# %%
FOLD = 4

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --adv_sift $ADV_SIFT --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --adam_bits $BNB
