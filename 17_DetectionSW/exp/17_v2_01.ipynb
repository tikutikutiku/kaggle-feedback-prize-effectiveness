# %%
VERSION = '17_v2_01'
FOLD_PATH = '../../00_EDA/00_v2_05/result/'
MODEL = 'facebook/bart-base'
#'microsoft/deberta-v3-large'
#'roberta-base'
#'microsoft/deberta-v3-base'
#'funnel-transformer/xlarge'
#'ahotrod/electra_large_discriminator_squad2_512'
#'funnel-transformer/xlarge'
#'microsoft/deberta-large'
#'anferico/bert-for-patents'
#'microsoft/deberta-v3-base'
#'microsoft/cocolm-large'
LR = 2e-5
HEAD_LR = 2e-4
SEED = 100
TRN_BS = 1
VAL_BS = 1
ACCUM_STEP = 1 #16
EPOCHS = 6 #2
STOP_EPOCH = 6 #2
RESTART = 1
HIDDEN_DROP_PROB = 0.1
P_DROP = 0.5
#RNN = 'none'
WARMUP_RATIO = 0.05 #0.1
#LOSS = 'xentropy'
#HEAD = 'simple'
#AUG = 'false' #'mixup'
#MIXUP_ALPHA = 1.0
#P_AUG = 0
#AUG_STOP_EPOCH = 2
#MSD = 'false'
#MULTI_LAYERS = 1
EVAL_STEP = -1 #100
#NUM_LABELS = 3
#NUM_LABELS_2 = 7
#ADV_SIFT = 'false'
FP16 ='false'
WD = 0.01
#FREEZE = 'false'
#MAX_LENGTH = 1024
#MULTI_TASK = 'false'
#W_MT = 1.0 #0.5
#PREPROCESSED_DATA_PATH = '../../00_EDA/00_v2_01/result/train.csv'
#'../../00_EDA/00_v1_09/result/train.csv'
#AWP = 'false'
#AWP_LR = 1.0
#AWP_EPS = 0.01
#AWP_START_EPOCH = 1
MASK_PROB = 0.8
MASK_RATIO = 0.3
CP = 'false'
SCHEDULER = 'cosine_hard'
NUM_CYCLES = EPOCHS

WINDOW_SIZE = 512
INNER_LEN = 384
EDGE_LEN = 64

# %%
FOLD = 0

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--warmup_ratio $WARMUP_RATIO \
--epochs $EPOCHS --accumulate_grad_batches $ACCUM_STEP --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--check_pointing $CP --scheduler $SCHEDULER --num_cycles $NUM_CYCLES \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN
# Out:
# torch 1.10.2
# train_df.shape =  (144293, 8)
# load folds...
# trn_df.shape =  (115526, 8)
# val_df.shape =  (28767, 8)
# 2022-07-19 19:44:04.192542: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-07-19 19:44:04.192563: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Loaded 12475 samples.
# Loaded 3119 samples.
# num_train_steps =  74850
# self.warmup_ratio =  0.05
# self.num_train_steps =  74850
# num_warmup_steps =  3742
#
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████| 12475/12475 [31:34<00:00,  6.58it/s, loss=3.71, score=0.421]
# 100%|███████████████████████████████████████| 3119/3119 [06:17<00:00,  8.27it/s]
# epoch 1: trn_loss = 3.7120, val_loss = 2.7447, trn_score = 0.4207, val_score = 0.6241
# trn_obj_loss=1.9720, trn_reg_loss=0.5517, trn_cls_loss=1.1883
# val_obj_loss=1.4160, val_reg_loss=0.3965, val_cls_loss=0.9322
# model (best loss) saved
# model (best score) saved
#
# lr :  [3.226328942446709e-06, 3.226328942446709e-06, 3.226328942446709e-05]
# 100%|███████████████| 12475/12475 [32:24<00:00,  6.42it/s, loss=2.93, score=0.6]
# 100%|███████████████████████████████████████| 3119/3119 [06:12<00:00,  8.37it/s]
# epoch 2: trn_loss = 2.9347, val_loss = 2.6294, trn_score = 0.6000, val_score = 0.6475
# trn_obj_loss=1.5231, trn_reg_loss=0.4281, trn_cls_loss=0.9835
# val_obj_loss=1.3271, val_reg_loss=0.3883, val_cls_loss=0.9140
# model (best loss) saved
# model (best score) saved
#
# lr :  [2.1080236502005456e-06, 2.1080236502005456e-06, 2.1080236502005457e-05]
# 100%|█████████████| 12475/12475 [33:12<00:00,  6.26it/s, loss=2.78, score=0.633]
# 100%|███████████████████████████████████████| 3119/3119 [06:24<00:00,  8.12it/s]
# epoch 3: trn_loss = 2.7825, val_loss = 2.5286, trn_score = 0.6334, val_score = 0.6596
# trn_obj_loss=1.4383, trn_reg_loss=0.4032, trn_cls_loss=0.9410
# val_obj_loss=1.2964, val_reg_loss=0.3603, val_cls_loss=0.8719
# model (best loss) saved
# model (best score) saved
#
# lr :  [1.2049304940972173e-06, 1.2049304940972173e-06, 1.2049304940972173e-05]
# 100%|█████████████| 12475/12475 [33:16<00:00,  6.25it/s, loss=2.68, score=0.655]
# 100%|███████████████████████████████████████| 3119/3119 [06:22<00:00,  8.15it/s]
# epoch 4: trn_loss = 2.6821, val_loss = 2.5026, trn_score = 0.6554, val_score = 0.6672
# trn_obj_loss=1.3841, trn_reg_loss=0.3851, trn_cls_loss=0.9129
# val_obj_loss=1.2787, val_reg_loss=0.3560, val_cls_loss=0.8679
# model (best loss) saved
# model (best score) saved
#
# lr :  [5.416765888981512e-07, 5.416765888981512e-07, 5.4167658889815124e-06]
# 100%|█████████████| 12475/12475 [32:43<00:00,  6.35it/s, loss=2.61, score=0.672]
# 100%|███████████████████████████████████████| 3119/3119 [06:12<00:00,  8.37it/s]
# epoch 5: trn_loss = 2.6052, val_loss = 2.5049, trn_score = 0.6720, val_score = 0.6718
# trn_obj_loss=1.3483, trn_reg_loss=0.3712, trn_cls_loss=0.8857
# val_obj_loss=1.2929, val_reg_loss=0.3486, val_cls_loss=0.8634
# model (best score) saved
#
# lr :  [1.3634869556363505e-07, 1.3634869556363505e-07, 1.3634869556363506e-06]
# 100%|█████████████| 12475/12475 [32:44<00:00,  6.35it/s, loss=2.54, score=0.686]
# 100%|███████████████████████████████████████| 3119/3119 [06:17<00:00,  8.27it/s]
# epoch 6: trn_loss = 2.5430, val_loss = 2.4969, trn_score = 0.6861, val_score = 0.6714
# trn_obj_loss=1.3143, trn_reg_loss=0.3599, trn_cls_loss=0.8688
# val_obj_loss=1.2881, val_reg_loss=0.3441, val_cls_loss=0.8647
# model (best loss) saved
# epoch_best 6, val_loss_best 2.49691, val_score_best 0.67140
