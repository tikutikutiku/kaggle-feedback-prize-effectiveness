# %%
VERSION = '21_v2_10'
FOLD_PATH = '../../00_EDA/00_v2_05/result/'
#MODEL = 'microsoft/deberta-v3-large'
GENERATOR = 'microsoft/deberta-v3-large'
#'anferico/bert-for-patents'
#'microsoft/deberta-v3-base'
#'microsoft/cocolm-large'
LR = 8e-6
HEAD_LR = 8e-6
SEED = 2022
TRN_BS = 1
VAL_BS = 1
ACCUM_STEP = 1
EPOCHS = 10
HIDDEN_DROP_PROB = 0
P_DROP = 0.5
WARMUP_RATIO = 0.05
RATIO_MASKING = 0.25
EVAL_STEP = -1
FP16 = 'false'
STOP_EPOCH = 10

SCHEDULER = 'cosine_hard'
NUM_CYCLES = EPOCHS

CP = 'true'

WINDOW_SIZE = -100 #512
INNER_LEN = -100 #384
EDGE_LEN = -100 #64

MAX_LEN = -100 #512

GRAD_CLIP = 1000

# %%
FOLD = 0

# !python ../$VERSION/pretrain_mlm.py --generator $GENERATOR \
--version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --warmup_ratio $WARMUP_RATIO --ratio_masking $RATIO_MASKING \
--eval_step $EVAL_STEP --fp16 $FP16 --stop_epoch $STOP_EPOCH \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
--max_length $MAX_LEN --gradient_clip_val $GRAD_CLIP
# Out:
# torch 1.10.2
# train_df.shape =  (144293, 8)
# load folds...
# trn_df.shape =  (115526, 8)
# val_df.shape =  (28767, 8)
# 2022-07-28 22:52:02.857278: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-07-28 22:52:02.857299: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# create validation dataset...
# 100%|██████████████████████████████████████| 3119/3119 [00:06<00:00, 513.06it/s]
# create validation dataset, done
# self.warmup_ratio =  0.05
# self.num_train_steps =  124750
# num_warmup_steps =  6237
# lr :  [0.0, 0.0, 0.0]
# 100%|██████████████| 12475/12475 [59:54<00:00,  3.47it/s, loss=5.98, score=0.26]
# 100%|███████████████████████████████████████| 3119/3119 [13:52<00:00,  3.74it/s]
#
# epoch 1: trn_loss_gen = 5.9755, val_loss_gen = 3.7511, trn_score_gen = 0.2603, val_score_gen = 0.4389
# model_gen (best loss) saved
# model_gen (best score) saved
# lr :  [3.6691820713612822e-06, 3.6691820713612822e-06, 3.6691820713612822e-06]
# 100%|█████████████| 12475/12475 [59:39<00:00,  3.49it/s, loss=3.77, score=0.436]
# 100%|███████████████████████████████████████| 3119/3119 [13:11<00:00,  3.94it/s]
#
# epoch 2: trn_loss_gen = 3.7697, val_loss_gen = 3.2633, trn_score_gen = 0.4361, val_score_gen = 0.4911
# model_gen (best loss) saved
# model_gen (best score) saved
# lr :  [3.0176252614001733e-06, 3.0176252614001733e-06, 3.0176252614001733e-06]
# 100%|██████████████| 12475/12475 [58:22<00:00,  3.56it/s, loss=3.35, score=0.48]
# 100%|███████████████████████████████████████| 3119/3119 [13:11<00:00,  3.94it/s]
#
# epoch 3: trn_loss_gen = 3.3484, val_loss_gen = 2.9497, trn_score_gen = 0.4798, val_score_gen = 0.5263
# model_gen (best loss) saved
# model_gen (best score) saved
# lr :  [2.3928605618038385e-06, 2.3928605618038385e-06, 2.3928605618038385e-06]
# 100%|█████████████| 12475/12475 [58:21<00:00,  3.56it/s, loss=3.08, score=0.508]
# 100%|███████████████████████████████████████| 3119/3119 [13:12<00:00,  3.93it/s]
#
# epoch 4: trn_loss_gen = 3.0781, val_loss_gen = 2.7580, trn_score_gen = 0.5079, val_score_gen = 0.5468
# model_gen (best loss) saved
# model_gen (best score) saved
# lr :  [1.8119270556491264e-06, 1.8119270556491264e-06, 1.8119270556491264e-06]
# 100%|█████████████| 12475/12475 [59:41<00:00,  3.48it/s, loss=2.89, score=0.527]
# 100%|███████████████████████████████████████| 3119/3119 [13:23<00:00,  3.88it/s]
#
# epoch 5: trn_loss_gen = 2.8946, val_loss_gen = 2.6147, trn_score_gen = 0.5271, val_score_gen = 0.5628
# model_gen (best loss) saved
# model_gen (best score) saved
# lr :  [1.2906684266138852e-06, 1.2906684266138852e-06, 1.2906684266138852e-06]
# 100%|█████████████| 12475/12475 [59:50<00:00,  3.47it/s, loss=2.76, score=0.543]
# 100%|███████████████████████████████████████| 3119/3119 [13:48<00:00,  3.77it/s]
#
# epoch 6: trn_loss_gen = 2.7566, val_loss_gen = 2.5132, trn_score_gen = 0.5427, val_score_gen = 0.5759
# model_gen (best loss) saved
# model_gen (best score) saved
# lr :  [8.433008573512057e-07, 8.433008573512057e-07, 8.433008573512057e-07]
# 100%|███████████| 12475/12475 [1:00:03<00:00,  3.46it/s, loss=2.65, score=0.555]
# 100%|███████████████████████████████████████| 3119/3119 [13:44<00:00,  3.78it/s]
#
# epoch 7: trn_loss_gen = 2.6526, val_loss_gen = 2.4294, trn_score_gen = 0.5546, val_score_gen = 0.5861
# model_gen (best loss) saved
# model_gen (best score) saved
# lr :  [4.820253143745128e-07, 4.820253143745128e-07, 4.820253143745128e-07]
#  19%|██▋           | 2362/12475 [11:14<43:13,  3.90it/s, loss=2.58, score=0.563]^C
#  19%|██▋           | 2362/12475 [11:14<48:09,  3.50it/s, loss=2.58, score=0.563]
# Traceback (most recent call last):
#   File "../21_v2_10/pretrain_mlm.py", line 115, in <module>
#     run(args, trn_df, val_df, pseudo_df=None)
#   File "/home/takesako2/programming/kaggle/54_Feedback2/21_MLM2/21_v2_10/run_pretrain_mlm.py", line 184, in run
#     loss_gen = loss_gen / args.accumulate_grad_batches
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/_tensor.py", line 307, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/autograd/__init__.py", line 156, in backward
#     allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
# KeyboardInterrupt
