# %%
VERSION = '21_v2_09'
FOLD_PATH = '../../00_EDA/00_v2_05/result/'
#MODEL = 'microsoft/deberta-v3-large'
GENERATOR = 'microsoft/deberta-v3-base'
#'anferico/bert-for-patents'
#'microsoft/deberta-v3-base'
#'microsoft/cocolm-large'
LR = 2e-5 #8e-6
HEAD_LR = 2e-5 #8e-6
SEED = 2022
TRN_BS = 1
VAL_BS = 1
ACCUM_STEP = 1
EPOCHS = 10
HIDDEN_DROP_PROB = 0
P_DROP = 0.5
WARMUP_RATIO = 0.05
RATIO_MASKING = 0.15 #0.25
EVAL_STEP = -1
FP16 = 'true'
STOP_EPOCH = 10

SCHEDULER = 'cosine_hard'
NUM_CYCLES = EPOCHS

CP = 'false'

WINDOW_SIZE = -100 #512
INNER_LEN = -100 #384
EDGE_LEN = -100 #64

MAX_LEN = -100 #512

GRAD_CLIP = 1000

# %%
FOLD = 0

# !python ../$VERSION/pretrain_mlm.py --generator $GENERATOR \
--version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --warmup_ratio $WARMUP_RATIO --ratio_masking $RATIO_MASKING \
--eval_step $EVAL_STEP --fp16 $FP16 --stop_epoch $STOP_EPOCH \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
--max_length $MAX_LEN --gradient_clip_val $GRAD_CLIP
# Out:
# torch 1.10.2
# train_df.shape =  (144293, 8)
# load folds...
# trn_df.shape =  (115526, 8)
# val_df.shape =  (28767, 8)
# 2022-07-28 16:24:31.717381: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-07-28 16:24:31.717404: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# create validation dataset...
# 100%|██████████████████████████████████████| 3119/3119 [00:06<00:00, 501.30it/s]
# create validation dataset, done
# self.warmup_ratio =  0.05
# self.num_train_steps =  124750
# num_warmup_steps =  6237
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████| 12475/12475 [23:59<00:00,  8.67it/s, loss=6.51, score=0.144]
# 100%|███████████████████████████████████████| 3119/3119 [12:00<00:00,  4.33it/s]
#
# epoch 1: trn_loss_gen = 6.5094, val_loss_gen = 4.1346, trn_score_gen = 0.1438, val_score_gen = 0.3991
# model_gen (best loss) saved
# model_gen (best score) saved
# lr :  [9.172955178403206e-06, 9.172955178403206e-06, 9.172955178403206e-06]
# 100%|███████████████| 12475/12475 [23:56<00:00,  8.68it/s, loss=4.28, score=0.2]
# 100%|███████████████████████████████████████| 3119/3119 [12:07<00:00,  4.29it/s]
#
# epoch 2: trn_loss_gen = 4.2791, val_loss_gen = 3.4869, trn_score_gen = 0.1999, val_score_gen = 0.4732
# model_gen (best loss) saved
# model_gen (best score) saved
# lr :  [7.544063153500434e-06, 7.544063153500434e-06, 7.544063153500434e-06]
# 100%|█████████████| 12475/12475 [23:58<00:00,  8.67it/s, loss=3.72, score=0.226]
# 100%|███████████████████████████████████████| 3119/3119 [12:09<00:00,  4.27it/s]
#
# epoch 3: trn_loss_gen = 3.7162, val_loss_gen = 3.1188, trn_score_gen = 0.2263, val_score_gen = 0.5128
# model_gen (best loss) saved
# model_gen (best score) saved
# lr :  [5.9821514045095975e-06, 5.9821514045095975e-06, 5.9821514045095975e-06]
# 100%|█████████████| 12475/12475 [24:00<00:00,  8.66it/s, loss=3.39, score=0.254]
# 100%|███████████████████████████████████████| 3119/3119 [12:09<00:00,  4.28it/s]
#
# epoch 4: trn_loss_gen = 3.3942, val_loss_gen = 2.8972, trn_score_gen = 0.2537, val_score_gen = 0.5385
# model_gen (best loss) saved
# model_gen (best score) saved
# lr :  [4.529817639122817e-06, 4.529817639122817e-06, 4.529817639122817e-06]
# 100%|█████████████| 12475/12475 [24:01<00:00,  8.65it/s, loss=3.17, score=0.287]
# 100%|███████████████████████████████████████| 3119/3119 [12:05<00:00,  4.30it/s]
#
# epoch 5: trn_loss_gen = 3.1746, val_loss_gen = 2.7265, trn_score_gen = 0.2871, val_score_gen = 0.5561
# model_gen (best loss) saved
# model_gen (best score) saved
# lr :  [3.2266710665347135e-06, 3.2266710665347135e-06, 3.2266710665347135e-06]
# 100%|█████████████| 12475/12475 [24:12<00:00,  8.59it/s, loss=3.01, score=0.318]
# 100%|███████████████████████████████████████| 3119/3119 [11:59<00:00,  4.33it/s]
#
# epoch 6: trn_loss_gen = 3.0088, val_loss_gen = 2.6066, trn_score_gen = 0.3177, val_score_gen = 0.5700
# model_gen (best loss) saved
# model_gen (best score) saved
# lr :  [2.1082521433780146e-06, 2.1082521433780146e-06, 2.1082521433780146e-06]
# 100%|█████████████| 12475/12475 [24:08<00:00,  8.61it/s, loss=2.88, score=0.354]
# 100%|███████████████████████████████████████| 3119/3119 [11:59<00:00,  4.33it/s]
#
# epoch 7: trn_loss_gen = 2.8843, val_loss_gen = 2.5084, trn_score_gen = 0.3544, val_score_gen = 0.5819
# model_gen (best loss) saved
# model_gen (best score) saved
# lr :  [1.205063285936282e-06, 1.205063285936282e-06, 1.205063285936282e-06]
# 100%|█████████████| 12475/12475 [24:10<00:00,  8.60it/s, loss=2.77, score=0.386]
# 100%|███████████████████████████████████████| 3119/3119 [11:56<00:00,  4.36it/s]
#
# epoch 8: trn_loss_gen = 2.7727, val_loss_gen = 2.4247, trn_score_gen = 0.3860, val_score_gen = 0.5913
# model_gen (best loss) saved
# model_gen (best score) saved
# lr :  [5.417369838267961e-07, 5.417369838267961e-07, 5.417369838267961e-07]
# 100%|██████████████| 12475/12475 [24:12<00:00,  8.59it/s, loss=2.69, score=0.41]
# 100%|███████████████████████████████████████| 3119/3119 [12:00<00:00,  4.33it/s]
#
# epoch 9: trn_loss_gen = 2.6886, val_loss_gen = 2.3582, trn_score_gen = 0.4102, val_score_gen = 0.5994
# model_gen (best loss) saved
# model_gen (best score) saved
# lr :  [1.3636400302271758e-07, 1.3636400302271758e-07, 1.3636400302271758e-07]
# 100%|█████████████| 12475/12475 [24:14<00:00,  8.58it/s, loss=2.63, score=0.439]
# 100%|███████████████████████████████████████| 3119/3119 [12:04<00:00,  4.30it/s]
#
# epoch 10: trn_loss_gen = 2.6316, val_loss_gen = 2.3058, trn_score_gen = 0.4388, val_score_gen = 0.6060
#  elapsed_time = 362.3 min
# model_gen (best loss) saved
# model_gen (best score) saved
# epoch_best 10, val_loss_best 2.30579, val_score_best 0.60598
