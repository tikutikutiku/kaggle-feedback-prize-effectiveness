# %%
VERSION = '21_v2_11'
FOLD_PATH = '../../00_EDA/00_v2_05/result/'
#MODEL = 'microsoft/deberta-v3-large'
GENERATOR = 'microsoft/deberta-v3-large'
#'anferico/bert-for-patents'
#'microsoft/deberta-v3-base'
#'microsoft/cocolm-large'
LR = 8e-6
HEAD_LR = 8e-6
SEED = 2022
TRN_BS = 1
VAL_BS = 1
ACCUM_STEP = 1
EPOCHS = 20 #10
HIDDEN_DROP_PROB = 0.1
P_DROP = 0.5
WARMUP_RATIO = 0.05
RATIO_MASKING = 0.25
EVAL_STEP = -1
FP16 = 'false'
STOP_EPOCH = 10

SCHEDULER = 'cosine_hard'
NUM_CYCLES = EPOCHS

CP = 'true'

WINDOW_SIZE = -100 #512
INNER_LEN = -100 #384
EDGE_LEN = -100 #64

MAX_LEN = -100 #512

GRAD_CLIP = 1000

# %%
FOLD = 0

# !python ../$VERSION/pretrain_mlm.py --generator $GENERATOR \
--version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --warmup_ratio $WARMUP_RATIO --ratio_masking $RATIO_MASKING \
--eval_step $EVAL_STEP --fp16 $FP16 --stop_epoch $STOP_EPOCH \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
--max_length $MAX_LEN --gradient_clip_val $GRAD_CLIP
# Out:
# torch 1.10.2
# train_df.shape =  (144293, 8)
# load folds...
# trn_df.shape =  (115526, 8)
# val_df.shape =  (28767, 8)
# 2022-07-29 07:36:23.876265: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-07-29 07:36:23.876285: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# special_tokens_dict =  {'additional_special_tokens': ['\n\n', '[LEAD]', '[POSITION]', '[CLAIM]', '[COUNTERCLAIM]', '[REBUTTAL]', '[EVIDENCE]', '[CONCLUDING STATEMENT]']}
# create validation dataset...
# 100%|██████████████████████████████████████| 3119/3119 [00:06<00:00, 501.61it/s]
# create validation dataset, done
# self.warmup_ratio =  0.05
# self.num_train_steps =  249500
# num_warmup_steps =  12475
# lr :  [0.0, 0.0, 0.0]
# 100%|████████████| 12475/12475 [1:02:15<00:00,  3.34it/s, loss=6.86, score=0.19]
# 100%|███████████████████████████████████████| 3119/3119 [13:49<00:00,  3.76it/s]
#
# epoch 1: trn_loss_gen = 6.8558, val_loss_gen = 4.1457, trn_score_gen = 0.1903, val_score_gen = 0.3881
# model_gen (best loss) saved
# model_gen (best score) saved
# lr :  [8e-06, 8e-06, 8e-06]
# 100%|███████████| 12475/12475 [1:02:29<00:00,  3.33it/s, loss=3.95, score=0.412]
# 100%|███████████████████████████████████████| 3119/3119 [13:54<00:00,  3.74it/s]
#
# epoch 2: trn_loss_gen = 3.9505, val_loss_gen = 3.4659, trn_score_gen = 0.4118, val_score_gen = 0.4680
# model_gen (best loss) saved
# model_gen (best score) saved
# lr :  [7.94544521361089e-06, 7.94544521361089e-06, 7.94544521361089e-06]
# 100%|███████████| 12475/12475 [1:02:31<00:00,  3.33it/s, loss=3.51, score=0.459]
# 100%|███████████████████████████████████████| 3119/3119 [13:50<00:00,  3.76it/s]
#
# epoch 3: trn_loss_gen = 3.5095, val_loss_gen = 3.1235, trn_score_gen = 0.4588, val_score_gen = 0.5037
# model_gen (best loss) saved
# model_gen (best score) saved
# lr :  [7.783268966802538e-06, 7.783268966802538e-06, 7.783268966802538e-06]
# 100%|███████████| 12475/12475 [1:02:36<00:00,  3.32it/s, loss=3.23, score=0.488]
# 100%|███████████████████████████████████████| 3119/3119 [13:51<00:00,  3.75it/s]
#
# epoch 4: trn_loss_gen = 3.2312, val_loss_gen = 2.9002, trn_score_gen = 0.4875, val_score_gen = 0.5279
# model_gen (best loss) saved
# model_gen (best score) saved
# lr :  [7.517895004825955e-06, 7.517895004825955e-06, 7.517895004825955e-06]
# 100%|███████████| 12475/12475 [1:02:44<00:00,  3.31it/s, loss=3.04, score=0.508]
# 100%|███████████████████████████████████████| 3119/3119 [14:06<00:00,  3.68it/s]
#
# epoch 5: trn_loss_gen = 3.0397, val_loss_gen = 2.7427, trn_score_gen = 0.5076, val_score_gen = 0.5465
# model_gen (best loss) saved
# model_gen (best score) saved
# lr :  [7.156562037585576e-06, 7.156562037585576e-06, 7.156562037585576e-06]
# 100%|████████████| 12475/12475 [1:02:55<00:00,  3.30it/s, loss=2.9, score=0.524]
# 100%|███████████████████████████████████████| 3119/3119 [14:08<00:00,  3.67it/s]
#
# epoch 6: trn_loss_gen = 2.8979, val_loss_gen = 2.6256, trn_score_gen = 0.5239, val_score_gen = 0.5596
# model_gen (best loss) saved
# model_gen (best score) saved
# lr :  [6.709126286502969e-06, 6.709126286502969e-06, 6.709126286502969e-06]
#  84%|██████████▉  | 10536/12475 [53:10<08:54,  3.63it/s, loss=2.79, score=0.535]^C
#  84%|██████████▉  | 10536/12475 [53:10<09:47,  3.30it/s, loss=2.79, score=0.535]
# Traceback (most recent call last):
#   File "../21_v2_11/pretrain_mlm.py", line 115, in <module>
#     run(args, trn_df, val_df, pseudo_df=None)
#   File "/home/takesako2/programming/kaggle/54_Feedback2/21_MLM2/21_v2_11/run_pretrain_mlm.py", line 174, in run
#     loss_gen, score_gen, output_data_gen = model_gen.training_step(data)
#   File "/home/takesako2/programming/kaggle/54_Feedback2/21_MLM2/21_v2_11/models_pretrain_generator.py", line 220, in training_step
#     loss = self.get_losses(logits[mask].reshape(-1,self.num_labels),
# KeyboardInterrupt
